# %% [markdown]
# <a href="https://colab.research.google.com/github/TahlonBrahic/8-Bit-Battler/blob/main/Tea_Production_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tea_production = pd.read_csv('https://raw.githubusercontent.com/TahlonBrahic/Tea-Production-Data-Science/main/DATA/Tea_crops_processed_production_quantity.csv')
tea_production.set_index('Country', inplace=True)
tea_production
# Out:
#                                   2010       2011       2012       2013  \
# Country
# Argentina                      92416.9    92892.2    82812.9    80423.0
# Bangladesh                     60000.0    60500.0    62524.0    66259.0
# Burundi                         6740.0     7000.0     8700.0     9000.0
# China                        1450000.0  1623000.0  1789753.0  1924457.0
# China, mainland              1450000.0  1623000.0  1789753.0  1924457.0
# India                         991182.0  1095460.0  1135070.0  1208780.0
# Indonesia                     150342.0   146603.0   143413.0   145855.0
# Iran (Islamic Republic of)     28000.0    29475.0    26500.0    26500.0
# Japan                          85000.0    82100.0    85900.0    84800.0
# Kenya                         399006.0   377912.0   369400.0   432400.0
# Malawi                         51589.0    47006.0    42490.0    46460.0
# Mozambique                      6380.0     6700.0     5000.0     6400.0
# ...

# %% [markdown]
# # Exploratory Analysis
# Who are the top 3 tea producing countries in the world.
# What are the top 3 growing tea producing countries in the world?

# %%
plt.plot(tea_production.loc['China'])
plt.title('Tea Production of China from 2010 to 2011 in kg')
plt.show()
